# %%
import requests

# %%
CONFIG_PATTERN = 'https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key={key}'

# %%
KEY = 'DoFKPPq7uZGPGBF63onOZyuu6HCUtm0P'

# %%
url = CONFIG_PATTERN.format(key=KEY)
r = requests.get(url)
config = r.json()

# %%
config
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2019-12-25T23:38:01-05:00',
#  'results': {'list_name': 'Hardcover Fiction',
#   'list_name_encoded': 'hardcover-fiction',
#   'bestsellers_date': '2019-12-21',
#   'published_date': '2020-01-05',
#   'published_date_description': 'latest',
#   'next_published_date': '',
#   'previous_published_date': '2019-12-29',
#   'display_name': 'Hardcover Fiction',
#   'normal_list_ends_at': 15,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 1,
#     'weeks_on_list': 68,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0735219095',
#     'primary_isbn13': '9780735219090',
#     'publisher': 'Putnam',
#     'description': 'In a quiet town on the North Carolina coast in 1969, a young woman who survived alone in the marsh becomes a murder suspect.',
#     'price': 0,
# ...

# %%
config
# Out:
# {'images': {'base_url': 'http://image.tmdb.org/t/p/',
#   'secure_base_url': 'https://image.tmdb.org/t/p/',
#   'backdrop_sizes': ['w300', 'w780', 'w1280', 'original'],
#   'logo_sizes': ['w45', 'w92', 'w154', 'w185', 'w300', 'w500', 'original'],
#   'poster_sizes': ['w92', 'w154', 'w185', 'w342', 'w500', 'w780', 'original'],
#   'profile_sizes': ['w45', 'w185', 'h632', 'original'],
#   'still_sizes': ['w92', 'w185', 'w300', 'original']},
#  'change_keys': ['adult',
#   'air_date',
#   'also_known_as',
#   'alternative_titles',
#   'biography',
#   'birthday',
#   'budget',
#   'cast',
#   'certifications',
#   'character_names',
#   'created_by',
#   'crew',
#   'deathday',
#   'episode',
#   'episode_number',
#   'episode_run_time',
#   'freebase_id',
#   'freebase_mid',
#   'general',
#   'genres',
#   'guest_stars',
#   'homepage',
#   'images',
#   'imdb_id',
#   'languages',
#   'name',
#   'network',
#   'origin_country',
#   'original_name',
#   'original_title',
# ...

# %%
IMG_PATTERN = 'http://api.themoviedb.org/3/movie/{imdbid}/images?api_key={key}' 
r = requests.get(IMG_PATTERN.format(key=KEY,imdbid='tt0095016'))
api_response = r.json()

# %%
posters = api_response['posters']
poster_urls = []
for poster in posters:
    rel_path = poster['file_path']
    url = "{0}{1}{2}".format(base_url, max_size, rel_path)
    poster_urls.append(url)

# %%
for nr, url in enumerate(poster_urls):
    r = requests.get(url)
    filetype = r.headers['content-type'].split('/')[-1]
    filename = 'poster_{0}.{1}'.format(nr+1,filetype) 
    with open(filename,'wb') as w:
        w.write(r.content)

# %%
api_response['posters']
# Out:
# [{'aspect_ratio': 0.6666666666666666,
#   'file_path': '/omoh8uH4U5psmdw3dGTzcO6eql8.jpg',
#   'height': 1500,
#   'iso_639_1': 'fr',
#   'vote_average': 5.522,
#   'vote_count': 6,
#   'width': 1000},
#  {'aspect_ratio': 0.6666666666666666,
#   'file_path': '/5o1bKwpCBB7g2Vv4HoDC7lZ5mbC.jpg',
#   'height': 1500,
#   'iso_639_1': 'de',
#   'vote_average': 5.388,
#   'vote_count': 4,
#   'width': 1000},
#  {'aspect_ratio': 0.6666666666666666,
#   'file_path': '/xnl0dQUHLPvJl6ezNIs9S88E22H.jpg',
#   'height': 2100,
#   'iso_639_1': 'it',
#   'vote_average': 5.384,
#   'vote_count': 2,
#   'width': 1400},
#  {'aspect_ratio': 0.6666666666666666,
#   'file_path': '/hJ6Asp1jCC6I01XUzRlkA5BSbbn.jpg',
#   'height': 1500,
#   'iso_639_1': 'ru',
#   'vote_average': 5.384,
#   'vote_count': 2,
#   'width': 1000},
#  {'aspect_ratio': 0.675,
#   'file_path': '/fiXHtnQpQiGVkMtyYnEfQ6Gtfx8.jpg',
#   'height': 1000,
#   'iso_639_1': 'en',
#   'vote_average': 5.354,
#   'vote_count': 44,
# ...

# %%
import urllib

# %%
def imdb_id_from_title(title):
    """ return IMDB id for search string

        Args::
            title (str): the movie title search string

        Returns: 
            str. IMDB id, e.g., 'tt0095016' 
            None. If no match was found

    """
    pattern = 'http://www.imdb.com/xml/find?json=1&nr=1&tt=on&q={movie_title}'
    url = pattern.format(movie_title=urllib.quote(title))
    r = requests.get(url)
    res = r.json()
    # sections in descending order or preference
    for section in ['popular','exact','substring']:
        key = 'title_' + section 
        if key in res:
            return res[key][0]['id']
